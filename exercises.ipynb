# %% [markdown]
# # Exercises: Python & File Operations
#
# Practice the same patterns from `Introduction_python.ipynb` and `Introduction_to_files.ipynb`.
# Fill in `# YOUR CODE HERE`, run the cell, match the expected output.

# %% [markdown]
# ---
# ## Part A: Python Basics

# %% [markdown]
# ### Exercise 1: Loops
# **a)** Use a `for` loop to print the **square** of numbers 1 to 5.
# **b)** Use a `while` loop to **count down** from 5 to 1.
#
# ```
# 1 4 9 16 25
# 5 4 3 2 1
# ```

# %%
# a) for loop — like Cell 3 in Introduction_python.ipynb
# YOUR CODE HERE


# b) while loop — like Cell 4
# YOUR CODE HERE

# %% [markdown]
# ### Exercise 2: If-Else
# Given `score = 72`, print `"Pass"` if score >= 50, otherwise `"Fail"`.
# Then change score to `35` and run again.
#
# ```
# Pass
# Fail
# ```

# %%
# Like Cell 6 in Introduction_python.ipynb
score = 72
# YOUR CODE HERE


score = 35
# YOUR CODE HERE

# %% [markdown]
# ### Exercise 3: Functions
# Write `multiply(a, b)` and `subtract(a, b)` with `return`. Print the results.
#
# ```
# 12
# 6
# ```

# %%
# Like Cell 8: def add(a,b): return a+b

# YOUR CODE HERE


print(multiply(3, 4))
print(subtract(10, 4))

# %% [markdown]
# ### Exercise 4: List
# Create a list `fruits = ["apple", "banana", "mango"]`. Append `"grape"` and `"orange"`.
# Print the list, its length, and each fruit using a `for` loop.
#
# ```
# ['apple', 'banana', 'mango', 'grape', 'orange']
# 5
# apple
# banana
# mango
# grape
# orange
# ```

# %%
# Like Cell 10: my_list.append(), for i in my_list: print(i)

# YOUR CODE HERE

# %% [markdown]
# ### Exercise 5: Dictionary
# Create a dictionary `student = {"name": "Somchai", "age": 22, "major": "AI"}`.
# Print each value by key. Then add a new key `"gpa"` with value `3.5` and print the full dict.
#
# ```
# Somchai
# 22
# AI
# {'name': 'Somchai', 'age': 22, 'major': 'AI', 'gpa': 3.5}
# ```

# %%
# Like Cell 12: data = {"name": "John", "age": 25}; print(data['name'])

# YOUR CODE HERE

# %% [markdown]
# ### Exercise 6: Class with `__init__` and methods
# Create a class `Employee` with:
# - `__init__(self, name, salary)`
# - `getName(self)` — returns the name
# - `getBonus(self)` — returns `salary * 0.1`
#
# ```
# Suda
# 5000.0
# ```

# %%
# Like Cell 14: class math: def __init__, def getName

# YOUR CODE HERE


e = Employee("Suda", 50000)
print(e.getName())
print(e.getBonus())

# %% [markdown]
# ### Exercise 7: `@classmethod` and `@staticmethod`
# Create a class `Company` with:
# - A class variable `company_name = "AIS"`
# - `@classmethod get_company(cls)` — returns `cls.company_name`
# - `@staticmethod multiply(a, b)` — returns `a * b`
#
# ```
# AIS
# 20
# ```

# %%
# Like Cells 16 and 18: @classmethod get_school, @staticmethod add

# YOUR CODE HERE


print(Company.get_company())
print(Company.multiply(4, 5))

# %% [markdown]
# ### Exercise 8: Wrapper and Decorator
# **a)** Write a `logger` wrapper that prints `"Start"` before and `"End"` after calling a function. Wrap `greet()` **manually**.
# **b)** Do the same using `@logger` decorator syntax.
#
# ```
# Start
# Hello, World!
# End
# ```

# %%
# a) Manual wrapping — like Cell 20

# YOUR CODE HERE: define greet() and logger(func), then wrap manually



# b) Decorator syntax — like Cell 22

# YOUR CODE HERE: use @logger on greet()

# %% [markdown]
# ### Exercise 9: Timer Decorator with `*args, **kwargs`
# Write a `timer` decorator (like Cell 25) that measures execution time. Apply it to a `slow_add(a, b)` function that sleeps 1 second then returns `a + b`.
#
# ```
# Time: ~1.00 seconds
# 30
# ```

# %%
import time

# Like Cell 25: def timer(func): def inner(*args, **kwargs): ...

# YOUR CODE HERE


print(slow_add(10, 20))

# %% [markdown]
# ### Exercise 10: `*args` and `**kwargs`
# **a)** Write `average(*args)` that returns the average of any number of values.
# **b)** Write `show_info(**kwargs)` that prints each key-value pair.
# **c)** Write `combined(*args, **kwargs)` that prints both.
#
# ```
# 5.0
# name = Suda
# role = Engineer
# Positional: (10, 20)
# Keyword: {'city': 'Bangkok'}
# ```

# %%
# Like Cells 29, 31, 32

# a) YOUR CODE HERE


# b) YOUR CODE HERE


# c) YOUR CODE HERE


print(average(2, 4, 6, 8))
show_info(name="Suda", role="Engineer")
combined(10, 20, city="Bangkok")

# %% [markdown]
# ### Exercise 11: NumPy Array
# Create `arr = np.array([[10, 20, 30], [40, 50, 60]])`. Multiply by 3. Print original and result.
#
# ```
# Original: [[10 20 30] [40 50 60]]
# Result:   [[ 30  60  90] [120 150 180]]
# ```

# %%
# Like Cell 36: np.array, arr * 2
import numpy as np

# YOUR CODE HERE

# %% [markdown]
# ### Exercise 12: Matplotlib — Line Plot, Bar Chart, Heatmap
# Using the array from Exercise 11:
# - **a)** Line plot of both rows with labels, title `"Line Plot"`, and legend (like Cell 39)
# - **b)** Bar chart of both rows (like Cell 41)
# - **c)** Heatmap with colorbar (like Cell 43)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

arr = np.array([[10, 20, 30], [40, 50, 60]])

# a) Line plot — like Cell 39
# YOUR CODE HERE

# %%
# b) Bar chart — like Cell 41
# YOUR CODE HERE

# %%
# c) Heatmap — like Cell 43
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part B: File Operations

# %% [markdown]
# ### Exercise 13: Check File Existence
# Using `os.path.exists()` and `os.path.isfile()`, check these three paths:
# `"intents.json"`, `"training_data.jsonl"`, `"nonexistent.txt"`
#
# ```
# intents.json        — exists: True,  is_file: True
# training_data.jsonl  — exists: True,  is_file: True
# nonexistent.txt      — exists: False, is_file: False
# ```

# %%
# Like Cells 4 and 6 in Introduction_to_files.ipynb
import os

files = ["intents.json", "training_data.jsonl", "nonexistent.txt"]

# YOUR CODE HERE

# %% [markdown]
# ### Exercise 14: Pathlib
# Use `pathlib.Path` to check if `"intents.json"` exists and is a file (like Cell 8).
# Then do the same for `"nonexistent.txt"`.
#
# ```
# intents.json: File exists, Valid file
# nonexistent.txt: File does not exist
# ```

# %%
# Like Cell 8: Path("info.txt"), file.exists(), file.is_file()
from pathlib import Path

# YOUR CODE HERE

# %% [markdown]
# ### Exercise 15: Read a File
# Create a file `"sample.txt"` with 3 lines, then:
# - **a)** Read the **entire file** using `f.read()` (like Cell 10)
# - **b)** Read the **first line** using `f.readline()` (like Cell 12)
# - **c)** Read the **second line** using `f.readlines()[1]` (like Cell 14)

# %%
# First, create the file
with open("sample.txt", "w") as f:
    f.write("Line one\nLine two\nLine three")

# a) Read entire file — like Cell 10
# YOUR CODE HERE


# b) Read first line — like Cell 12
# YOUR CODE HERE


# c) Read second line — like Cell 14
# YOUR CODE HERE

# %% [markdown]
# ### Exercise 16: Write and Append
# **a)** Write `"Hello AIS"` to a new file `"output.txt"`.
# **b)** Append `"\nWelcome to training"` to the same file.
# **c)** Read it back and print. Then clean up (`os.remove`).
#
# ```
# Hello AIS
# Welcome to training
# ```

# %%
import os

# Like Cell 16: open("info.txt", "a"), f.write()

# a) Write — YOUR CODE HERE


# b) Append — YOUR CODE HERE


# c) Read back and print — YOUR CODE HERE


# Clean up
os.remove("output.txt")
os.remove("sample.txt")

# %% [markdown]
# ### Exercise 17: Error Handling
# Try to open `"missing_file.txt"`. Catch `FileNotFoundError` and print `"File missing"`.
# Then try to open `"intents.json"` — it should succeed, print `"File loaded OK"`.
#
# ```
# File missing
# File loaded OK
# ```

# %%
# Like Cell 18: try: open("example.txt") except FileNotFoundError:

# Test 1: missing file — YOUR CODE HERE


# Test 2: existing file — YOUR CODE HERE
